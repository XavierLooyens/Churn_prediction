# %%
import pandas as pd

# %%
#Importing Members data
members_df= pd.read_csv("/Users/xavier/code/XavierLooyens/Churn_prediction/raw_data/members_v3.csv")

# %%
members_df['bd'].value_counts()/len(members_df)
# Out:
# bd
#  0       6.706896e-01
#  22      1.657441e-02
#  21      1.633421e-02
#  20      1.631619e-02
#  27      1.518124e-02
#              ...
#  140     1.477220e-07
# -14      1.477220e-07
# -512     1.477220e-07
# -6998    1.477220e-07
#  573     1.477220e-07
# Name: count, Length: 386, dtype: float64

# %%
members_df['bd'].value_counts()
# Out:
# bd
#  0       4540215
#  22       112200
#  21       110574
#  20       110452
#  27       102769
#           ...
#  140           1
# -14            1
# -512           1
# -6998          1
#  573           1
# Name: count, Length: 386, dtype: int64

# %%
len(members_df)
# Out:
# 6769473

# %%
members_df['bd'].describe()
# Out:
# count    6.769473e+06
# mean     9.795794e+00
# std      1.792590e+01
# min     -7.168000e+03
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.100000e+01
# max      2.016000e+03
# Name: bd, dtype: float64

# %%
#Importing Train data
train_df= pd.read_csv("/Users/xavier/code/XavierLooyens/Churn_prediction/raw_data/train_v2.csv")
train_df
# Out:
#                                                 msno  is_churn
# 0       ugx0CjOMzazClkFzU2xasmDZaoIqOUAZPsH1q0teWCg=         1
# 1       f/NmvEzHfhINFEYZTR05prUdr+E+3+oewvweYz9cCQE=         1
# 2       zLo9f73nGGT1p21ltZC3ChiRnAVvgibMyazbCxvWPcg=         1
# 3       8iF/+8HY8lJKFrTc7iR9ZYGCG2Ecrogbc2Vy5YhsfhQ=         1
# 4       K6fja4+jmoZ5xG6BypqX80Uw/XKpMgrEMdG2edFOxnA=         1
# ...                                              ...       ...
# 970955  OHnZbu+EVaP+vN7Z+OfT5OMcp90MWFZonmM0o3pb8FY=         0
# 970956  S92bDK//uI6hk3u1vuApro0qJBQOToBozZ7lL1yTC+w=         0
# 970957  eUa3xo16vpAjr43Cjlb6Kjf1NTILYyJIkBayJQdXWnw=         0
# 970958  iZE41tbAQ65rJq60olkJT4BJzuUAYgQdfbEemXe/TTk=         0
# 970959  oECkzJik4wKsbOEVY6UACLbmgM8qymFdb5cJaHrodY8=         0
#
# [970960 rows x 2 columns]

# %%
#members and train merge
members_and_train_df = members_df.merge(train_df, on='msno', how='left')

# %%
#churned members
churned_df = members_and_train_df[members_and_train_df['is_churn'] ==1]
churned_df
# Out:
#                                                  msno  city  bd  gender  \
# 10       OoDwiKZM+ZGr9P3fRivavgOtglTEaNfWJO4KaJcTTts=     1   0     NaN
# 39       XmV2kHCnqnQf4oTJ4LCS7F02cpxnzqGIDDRGHe4dw8c=    22  31  female
# 47       75A0yqLXt/ZZ+DY30gjRr/mJG8rDOexVswfVw1dVbt0=    15  21    male
# 68       STXWC0VvMgKZRWGdd4rv1dmwlcUFjvW4vHqo00YWZfg=     5  27    male
# 74       7oCpSPj4+SdVJLfDRc+tN5HLp2R1DRozaWsTpbLTz5g=    15  21  female
# ...                                               ...   ...  ..     ...
# 6768530  FmoAC+4dukAZXgM5jC3dwWWmQuZegskozBQmITr29ak=     1   0     NaN
# 6768858  4mpl6Z7Eac/luoJYHCo2qqegd5l5/UR4hydsDNOUQgI=     1  17    male
# 6769141  OkmWeuclYKViMDDkd637R/RN7O6LzXyLeTzBRlDQA6A=     5  19    male
# 6769278  baJjuMzei5ZJi9LhNUH01imIr2u/XCfUEW9Ym9OJcA0=     1   0     NaN
# 6769369  7pUEHRm2pMJTDewz/nyntfo91Atbx9tcNfXknFWMucg=     1   0     NaN
#
#          registered_via  registration_init_time  is_churn
# ...

# %%
#not-churned members
not_churned_df = members_and_train_df[members_and_train_df['is_churn'] ==0]
not_churned_df
# Out:
#                                                  msno  city  bd  gender  \
# 1        +tJonkh+O1CA796Fm5X60UMOtB6POHAwPjbTRVl/EuU=     1   0     NaN
# 5        yLkV2gbZ4GLFwqTOXLVHz0VGrMYcgBGgKZ3kj9RiYu8=     4  30    male
# 9        I0yFvqMoNkM8ZNHb617e1RBzIS/YRKemHO7Wj13EtA0=    13  63    male
# 13       4De1jAxNRABoyRBDZ82U0yEmzYkqeOugRGVNIf92Xb8=     4  28  female
# 27       GqYHRxlZChiZvB1uzR410wcQzuxqZNZci4AzOTzkAao=     5  27    male
# ...                                               ...   ...  ..     ...
# 6769443  dz8iQV2eZCBZo1DjKL7OifsiyzGf3xyMaCFDOJHVeyc=     1   0     NaN
# 6769465  OL6joplCKThE1pZD+AQDnj3kZiC45qzpndlDIRSyPQI=     1   0     NaN
# 6769466  O11rAa17ANM6DGMMVb9L2vwCQFv/S6SR3SDB1nGuOAc=     1   0     NaN
# 6769467  tyoRqQ72Y2oCcqvdaIxG8T0Hs9DZvuuM8IeTwhxtdBQ=     6  26  female
# 6769469  nWjH7glPkZ7jOVaCRwwjlpmp0T1hSWdv8hMJxiWCwKc=     1   0     NaN
#
#          registered_via  registration_init_time  is_churn
# ...

# %%
members_and_train_df['gender'].value_counts().plot(kind='bar', title = "Distribution of Male and Female overall")
print(members_and_train_df['gender'].value_counts())
print(members_and_train_df['gender'].value_counts()/len(members_and_train_df))
print("the male/female ratio in the overall data is: ") 
print((members_and_train_df['gender']=='male').sum()/((members_and_train_df['gender']=='female').sum()))
# Out:
# gender
# male      1195355
# female    1144613
# Name: count, dtype: int64
# gender
# male      0.176580
# female    0.169085
# Name: count, dtype: float64
# the male/female ration is:
# 1.04433114074364

# %%
churned_df['gender'].value_counts().plot(kind='bar', title = "Distribution of Male and Female churners")
print(churned_df['gender'].value_counts())
print(churned_df['gender'].value_counts()/len(churned_df))
print("the male/female ratio in the churn data is: ") 
print((churned_df['gender']=='male').sum()/((churned_df['gender']=='female').sum()))
# Out:
# gender
# male      26396
# female    23940
# Name: count, dtype: int64
# gender
# male      0.324084
# female    0.293930
# Name: count, dtype: float64
# the male/female ratio in the churn data is:
# 1.1025898078529657

# %%
not_churned_df['gender'].value_counts().plot(kind='bar', title = "Distribution of Male and Female not-churners")
print(not_churned_df['gender'].value_counts())
print(not_churned_df['gender'].value_counts()/len(not_churned_df))
print("the male/female ratio in the not_churn data is: ") 
print((not_churned_df['gender']=='male').sum()/((not_churned_df['gender']=='female').sum()))
# Out:
# gender
# male      178165
# female    160404
# Name: count, dtype: int64
# gender
# male      0.228558
# female    0.205773
# Name: count, dtype: float64
# the male/female ratio in the not_churn data is:
# 1.1107266651704446

# %%
#Importing Transactions data
transactions_df= pd.read_csv("/Users/xavier/code/XavierLooyens/Churn_prediction/raw_data/transactions_v2.csv")

# %%
# converting transaction_date and membership_date to datetime object
transactions_df['transaction_date'] = pd.to_datetime(transactions_df['transaction_date'], format='%Y%m%d')
transactions_df['membership_expire_date'] = pd.to_datetime(transactions_df['membership_expire_date'], format='%Y%m%d')

# %%
# removing duplicates and leaving only the latest transaction date
transactions_df_lt = transactions_df.loc[transactions_df.groupby('msno').transaction_date.idxmax()]

# %%
# creating remaining plan duration column
transactions_df_lt['remaining_plan_duration'] = transactions_df_lt['membership_expire_date'] - transactions_df_lt['transaction_date']

# %%
#creating discount column
transactions_df_lt['is_discount'] = transactions_df_lt.apply(lambda x: '0' if (x['actual_amount_paid'] -x['plan_list_price'])>=0 else '1', axis=1)

# %%
# Importing user logs data
user_logs_df = pd.read_csv("/Users/xavier/code/XavierLooyens/Churn_prediction/raw_data/user_logs_v2.csv")

# %%
# Converting date into datetime object
user_logs_df['date'] = pd.to_datetime(user_logs_df['date'], format='%Y%m%d')

# %%
#copy of transactions with only latest transaction date
latest_transactions_per_msno = transactions_df_lt[['msno', 'transaction_date']]

# %%
#merge 
merged_df = user_logs_df.merge(latest_transactions_per_msno, on='msno', how='left')

# %%
# drop msno's where transaction date is NaN
merged_df = merged_df.dropna(subset=['transaction_date'])

# %%
#day difference 
merged_df['day_difference'] = merged_df['date'] - merged_df['transaction_date']

#boolean mask
positive_difference_mask = day_difference.dt.days >= 0

#boolean mask filtering
filtered_df = merged_df[positive_difference_mask]

# %%
avg_usage_df = filtered_df.groupby('msno').agg({'num_25': 'sum', 'day_difference': 'first'}).reset_index()

# %%
filtered_df
# Out:
#                                                 msno  num_25 day_difference
# 0       +++IZseRRiQS9aaSkH6cMYU6bGDcxUieAi/tH67sC5s=      86       159 days
# 1       +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=     115         9 days
# 2       +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=       0         0 days
# 3       +++snpr7pmobhLKUgSHTv/mpkqgBT0tQJ0zQj6qKrqc=      17         0 days
# 4       ++/9R3sX37CjxbY/AaGvbwr3QkwElKBCtSvVzhCBDOk=      79         6 days
# ...                                              ...     ...            ...
# 874238  zzy0oyiTnRTo5Mbg23oKbBkf9eoaS7+eU4V+d14bzfY=      45       112 days
# 874239  zzy7iqSpfcRq7R4hmKKuhI+CJRs79a6pteqEggpiNO0=     136         5 days
# 874240  zzyHq6TK2+cBkeGFUHvh12Z7UxFZiSM7dOOSllSBPDw=      17         3 days
# 874241  zzz1Dc3P9s53HAowRTrm3fNsWju5yeN4YBfNDq7Z99Q=       3         0 days
# 874242  zzzF1KsGfHH3qI6qiSNSXC35UXmVKMVFdxkp7xmDMc0=       8         0 days
#
# [874243 rows x 3 columns]

# %%
transactions_df_lt.tail(10)
# Out:
#                                                  msno  payment_method_id  \
# 57193    zzx4hKiyR9XFEGAr7SAjcCPbKJCZ+IqegWL7dPjPwZk=                 41
# 1352703  zzxIjlrMxRzNVDD6XqUDRBqkWn7OJ9mzFmFQlfLtLCE=                 36
# 256989   zzxPS8+wCuE4HE85EDp4WBHgS5l548vfwXJbQq1HZ9I=                 39
# 979879   zzxZeMFx2fjfKZigMnJa2w0EmloDbm8+8nTf/o/00GY=                 41
# 1044471  zzxi7n5xoTYo9Q3VTygLWvl/rBDcexwaeAry0yK7Q0E=                 41
# 328446   zzy0oyiTnRTo5Mbg23oKbBkf9eoaS7+eU4V+d14bzfY=                 22
# 751351   zzy7iqSpfcRq7R4hmKKuhI+CJRs79a6pteqEggpiNO0=                 36
# 1359816  zzyHq6TK2+cBkeGFUHvh12Z7UxFZiSM7dOOSllSBPDw=                 29
# 357121   zzz1Dc3P9s53HAowRTrm3fNsWju5yeN4YBfNDq7Z99Q=                 39
# 972770   zzzF1KsGfHH3qI6qiSNSXC35UXmVKMVFdxkp7xmDMc0=                 40
#
#          payment_plan_days  plan_list_price  actual_amount_paid  \
# 57193                   30               99                  99
# ...
