# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, FunctionTransformer
from sklearn.compose import ColumnTransformer
import warnings

# %%
data_df= pd.read_csv("../notebooks/.test_transformed_df1.csv")

# %% [markdown]
# ## Import data

# %%
data_df = data_df.sample(frac=1, random_state=42)

# %%
data_df = data_df.drop(['Unnamed: 0','msno', 'bd', 'payment_method_id', 'city', 'registered_via'], axis=1)

# %% [markdown]
# ## Which scaler to use for which feature

# %%
robust_features = [               'remaining_plan_duration', 
          'usage_from_ltd',
              'payment_plan_days',
              'plan_list_price',
              'actual_amount_paid',
             'num_50',
              'num_75',
              'num_985',
              
              'expire_year',
              'last_transaction_year'
             ]
minmax_features = ['registration_year']
normal_features = [ 'num_25',
              
              'num_100',
              'num_unq',
              'total_secs',]

# %% [markdown]
# ## Pipeline

# %%
# Build the pipeline with the different steps
robust_pipeline = make_pipeline(RobustScaler())
minmax_pipeline = make_pipeline(MinMaxScaler())
log_pipeline = make_pipeline( 
    FunctionTransformer(np.log1p, validate=True),
    StandardScaler())

preprocessor_new = ColumnTransformer(
    transformers=[
        ('Robust', robust_pipeline, robust_features),
        ('MinMax', minmax_pipeline, minmax_features),
        ('Log', log_pipeline, normal_features)
    ], remainder='passthrough'
)

# %%
preprocessor_new
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('Robust',
#                                  Pipeline(steps=[('robustscaler',
#                                                   RobustScaler())]),
#                                  ['remaining_plan_duration', 'usage_from_ltd',
#                                   'payment_plan_days', 'plan_list_price',
#                                   'actual_amount_paid', 'num_50', 'num_75',
#                                   'num_985', 'expire_year',
#                                   'last_transaction_year']),
#                                 ('MinMax',
#                                  Pipeline(steps=[('minmaxscaler',
#                                                   MinMaxScaler())]),
#                                  ['registration_year']),
#                                 ('Log',
#                                  Pipeline(steps=[('functiontransformer',
#                                                   FunctionTransformer(func=<ufunc 'log1p'>,
#                                                                       validate=True)),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['num_25', 'num_100', 'num_unq',
#                                   'total_secs'])])

# %%
#create X and y
X = data_df.drop(['is_churn'], axis=1)
y= data_df['is_churn']

# %%
X
# Out:
#        payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 39371                7.0              0.0                 0.0            0.0
# 20602               30.0            149.0               149.0            1.0
# 29020               30.0            180.0               180.0            0.0
# 13871               30.0            149.0               149.0            1.0
# 44798               30.0            180.0               180.0            1.0
# ...                  ...              ...                 ...            ...
# 44732               30.0            149.0               149.0            0.0
# 54343               30.0            149.0               149.0            1.0
# 38158               30.0             99.0                99.0            1.0
# 860                 30.0             99.0                99.0            1.0
# 15795               30.0             99.0                99.0            1.0
#
#        is_cancel  remaining_plan_duration  is_discount  num_25  num_50  \
# 39371        0.0                      451            0    69.0    16.0
# 20602        0.0                       30            0     6.0     2.0
# 29020        0.0                       32            0    19.0     5.0
# 13871        0.0                       51            0     1.0     1.0
# 44798        1.0                       -2            0     0.0     1.0
# ...          ...                      ...          ...     ...     ...
# 44732        0.0                       33            0   386.0   112.0
# 54343        1.0                        1            0     6.0     4.0
# 38158        1.0                        0            0     7.0     1.0
# 860          0.0                       31            0   123.0    22.0
# 15795        0.0                       31            0    11.0     4.0
#
#        num_75  ...  expire_year  expire_month_sin  expire_month_cos  \
# 39371    10.0  ...         2018          0.500000     -8.660254e-01
# 20602     4.0  ...         2017          0.866025     -5.000000e-01
# 29020     5.0  ...         2017          0.866025     -5.000000e-01
# 13871     0.0  ...         2017          0.500000     -8.660254e-01
# 44798     0.0  ...         2017          1.000000      6.123234e-17
# ...       ...  ...          ...               ...               ...
# 44732    69.0  ...         2017          0.866025     -5.000000e-01
# 54343     4.0  ...         2017          1.000000      6.123234e-17
# 38158     4.0  ...         2017          1.000000      6.123234e-17
# 860       8.0  ...         2017          0.866025     -5.000000e-01
# 15795     3.0  ...         2017          0.866025     -5.000000e-01
#
#        expire_day_sin  expire_day_cos  registration_year  \
# 39371       -0.299363       -0.954139               2016
# 20602       -0.998717       -0.050649               2006
# 29020       -0.485302       -0.874347               2016
# 13871       -0.897805       -0.440394               2007
# 44798        0.998717       -0.050649               2009
# ...               ...             ...                ...
# 44732        0.201299        0.979530               2015
# 54343       -0.988468        0.151428               2016
# 38158       -0.394356        0.918958               2012
# 860         -0.897805       -0.440394               2012
# 15795       -0.299363       -0.954139               2016
#
#        registration_month_sin  registration_month_cos  registration_day_sin  \
# 39371            5.000000e-01            8.660254e-01              0.571268
# 20602            5.000000e-01           -8.660254e-01              0.998717
# 29020            8.660254e-01            5.000000e-01              0.101168
# 13871            1.224647e-16           -1.000000e+00             -0.485302
# 44798            1.000000e+00            6.123234e-17             -0.937752
# ...                       ...                     ...                   ...
# 44732            5.000000e-01            8.660254e-01              0.790776
# 54343            1.224647e-16           -1.000000e+00             -0.201299
# 38158           -2.449294e-16            1.000000e+00             -0.988468
# 860              5.000000e-01           -8.660254e-01             -0.101168
# 15795            1.000000e+00            6.123234e-17             -0.299363
#
#        registration_day_cos
# 39371              0.820763
# 20602             -0.050649
# 29020             -0.994869
# 13871             -0.874347
# 44798              0.347305
# ...                     ...
# 44732             -0.612106
# 54343              0.979530
# 38158              0.151428
# 860               -0.994869
# 15795             -0.954139
#
# [55994 rows x 37 columns]

# %%
# Use fit on X_train and then transform both datasets
preprocessor_new.fit(X)
X_train_transformed = preprocessor_new.transform(X)

# %%
X_train_transformed
# Out:
# array([[ 1.61538462e+01, -2.64705882e-01, -2.30000000e+01, ...,
#          8.66025404e-01,  5.71268215e-01,  8.20763441e-01],
#        [-3.84615385e-02,  4.85294118e-01,  0.00000000e+00, ...,
#         -8.66025404e-01,  9.98716507e-01, -5.06491688e-02],
#        [ 3.84615385e-02,  0.00000000e+00,  0.00000000e+00, ...,
#          5.00000000e-01,  1.01168322e-01, -9.94869323e-01],
#        ...,
#        [-1.19230769e+00,  5.33823529e+00,  0.00000000e+00, ...,
#          1.00000000e+00, -9.88468324e-01,  1.51427778e-01],
#        [ 0.00000000e+00,  2.38235294e+00,  0.00000000e+00, ...,
#         -8.66025404e-01, -1.01168322e-01, -9.94869323e-01],
#        [ 0.00000000e+00, -1.76470588e-01,  0.00000000e+00, ...,
#          6.12323400e-17, -2.99363123e-01, -9.54139256e-01]])

# %%
# Convert transformed data back to DataFrame to ensure column order is maintained
X_train_transformed = pd.DataFrame(
    X_train_transformed, 
    columns=X.columns
)

# %%
X_train_transformed
# Out:
#        payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0              16.153846        -0.264706               -23.0          -7.45
# 1              -0.038462         0.485294                 0.0           0.00
# 2               0.038462         0.000000                 0.0           1.55
# 3               0.769231        -0.382353                 0.0           0.00
# 4              -1.269231        -0.397059                 0.0           1.55
# ...                  ...              ...                 ...            ...
# 55989           0.076923         2.529412                 0.0           0.00
# 55990          -1.153846         8.470588                 0.0           0.00
# 55991          -1.192308         5.338235                 0.0          -2.50
# 55992           0.000000         2.382353                 0.0          -2.50
# 55993           0.000000        -0.176471                 0.0          -2.50
#
#        is_cancel  remaining_plan_duration  is_discount    num_25  num_50  \
# 0      -3.040816                 0.588235     0.545455  0.333333     1.0
# 1       0.000000                -0.235294     0.000000 -0.333333     0.0
# 2       0.632653                -0.058824     0.090909  0.166667     0.0
# 3       0.000000                -0.294118    -0.363636 -0.333333     0.0
# 4       0.632653                -0.294118    -0.363636 -0.333333     0.0
# ...          ...                      ...          ...       ...     ...
# 55989   0.000000                 6.235294     5.909091  4.833333     0.0
# 55990   0.000000                -0.117647     0.000000 -0.083333     0.0
# 55991  -1.020408                -0.294118     0.000000 -0.250000     0.0
# 55992  -1.020408                 0.941176     0.363636  1.000000     0.0
# 55993  -1.020408                -0.117647    -0.090909  0.250000     0.0
#
#        num_75  ...   expire_year  expire_month_sin  expire_month_cos  \
# 0         0.0  ... -7.907757e-01         -0.612106          0.500000
# 1         0.0  ... -9.884683e-01          0.151428          0.866025
# 2         0.0  ... -2.993631e-01         -0.954139          0.866025
# 3         0.0  ... -2.449294e-16          1.000000          0.500000
# 4         0.0  ...  8.978045e-01         -0.440394          1.000000
# ...       ...  ...           ...               ...               ...
# 55989     0.0  ... -7.247928e-01          0.688967          0.866025
# 55990     0.0  ... -9.987165e-01         -0.050649          1.000000
# 55991     0.0  ... -3.943559e-01          0.918958          1.000000
# 55992     0.0  ... -8.978045e-01         -0.440394          0.866025
# 55993     0.0  ... -2.993631e-01         -0.954139          0.866025
#
#        expire_day_sin  expire_day_cos  registration_year  \
# 0       -8.660254e-01       -0.299363          -0.954139
# 1       -5.000000e-01       -0.998717          -0.050649
# 2       -5.000000e-01       -0.485302          -0.874347
# 3       -8.660254e-01       -0.897805          -0.440394
# 4        6.123234e-17        0.998717          -0.050649
# ...               ...             ...                ...
# 55989   -5.000000e-01        0.201299           0.979530
# 55990    6.123234e-17       -0.988468           0.151428
# 55991    6.123234e-17       -0.394356           0.918958
# 55992   -5.000000e-01       -0.897805          -0.440394
# 55993   -5.000000e-01       -0.299363          -0.954139
#
#        registration_month_sin  registration_month_cos  registration_day_sin  \
# 0                5.000000e-01            8.660254e-01              0.571268
# 1                5.000000e-01           -8.660254e-01              0.998717
# 2                8.660254e-01            5.000000e-01              0.101168
# 3                1.224647e-16           -1.000000e+00             -0.485302
# 4                1.000000e+00            6.123234e-17             -0.937752
# ...                       ...                     ...                   ...
# 55989            5.000000e-01            8.660254e-01              0.790776
# 55990            1.224647e-16           -1.000000e+00             -0.201299
# 55991           -2.449294e-16            1.000000e+00             -0.988468
# 55992            5.000000e-01           -8.660254e-01             -0.101168
# 55993            1.000000e+00            6.123234e-17             -0.299363
#
#        registration_day_cos
# 0                  0.820763
# 1                 -0.050649
# 2                 -0.994869
# 3                 -0.874347
# 4                  0.347305
# ...                     ...
# 55989             -0.612106
# 55990              0.979530
# 55991              0.151428
# 55992             -0.994869
# 55993             -0.954139
#
# [55994 rows x 37 columns]

# %% [markdown]
# ## Logistic Regresssion model

# %%
model = LogisticRegression(C= 2.58069,
                           solver='liblinear',
 max_iter= 2,
penalty= 'l1',
 class_weight= 'balanced')

model_no_hyperparams = LogisticRegression()

cv_results = cross_validate(model, X_train_transformed, y, cv=5, scoring='precision')

precision = cv_results['test_score'].mean()

warnings.filterwarnings('ignore')

# %%
cv_results
# Out:
# {'fit_time': array([0.05884385, 0.03540301, 0.05247521, 0.04340196, 0.03587604]),
#  'score_time': array([0.00842595, 0.00480223, 0.01079893, 0.00376892, 0.0036819 ]),
#  'test_score': array([0.95571679, 0.97522961, 0.95062924, 0.97351367, 0.963241  ])}

# %%
precision
# Out:
# 0.9636660612373207
