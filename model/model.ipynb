# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, FunctionTransformer
from sklearn.compose import ColumnTransformer
import warnings

# %%
org_data_df= pd.read_csv("../raw_data/churn_df_underbalanced.csv")

# %%
org_data_df = org_data_df.sample(frac=1, random_state=42)

# %%
org_data_df.head(2)
# Out:
#        Unnamed: 0                                          msno  is_churn  \
# 39371       35364  8OTTrmgne+Jb45ryTJXOv9IIZgiraVKD8QvbOsKVndE=         1
# 20602      957230  0/LAmLtLKEnNkG3Xr8RfGvhjeNJ6EoHbfSKBzjbcqF0=         0
#
#        payment_method_id  payment_plan_days  plan_list_price  \
# 39371               35.0                7.0              0.0
# 20602               37.0               30.0            149.0
#
#        actual_amount_paid  is_auto_renew  is_cancel  remaining_plan_duration  \
# 39371                 0.0            0.0        0.0                      451
# 20602               149.0            1.0        0.0                       30
#
#        ...  expire_year  expire_month_sin  expire_month_cos  expire_day_sin  \
# 39371  ...         2018          0.500000         -0.866025       -0.299363
# 20602  ...         2017          0.866025         -0.500000       -0.998717
#
#        expire_day_cos  registration_year  registration_month_sin  \
# 39371       -0.954139               2016                     0.5
# 20602       -0.050649               2006                     0.5
#
#        registration_month_cos  registration_day_sin  registration_day_cos
# 39371                0.866025              0.571268              0.820763
# 20602               -0.866025              0.998717             -0.050649
#
# [2 rows x 44 columns]

# %%
data_df = org_data_df.drop(['Unnamed: 0','msno', 'bd', 'payment_method_id', 'city', 'registered_via'], axis=1)
data_df.is_churn.value_counts()
ids = org_data_df.msno

# %%
robust_features = ['remaining_plan_duration', 
          'usage_from_ltd',
              'payment_plan_days',
              'plan_list_price',
              'actual_amount_paid',
             'num_50',
              'num_75',
              'num_985',
              'expire_year',
              'last_transaction_year'
             ]
minmax_features = ['registration_year']
normal_features = [ 'num_25',
              
              'num_100',
              'num_unq',
              'total_secs',]

# %%
# Build the pipeline with the different steps
robust_pipeline = make_pipeline(RobustScaler())
minmax_pipeline = make_pipeline(MinMaxScaler())
log_pipeline = make_pipeline( 
    FunctionTransformer(np.log1p, validate=True),
    StandardScaler())

preprocessor_new = ColumnTransformer(
    transformers=[
        ('Robust', robust_pipeline, robust_features),
        ('MinMax', minmax_pipeline, minmax_features),
        ('Log', log_pipeline, normal_features)
    ], remainder='passthrough'
)

preprocessor_new
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('Robust',
#                                  Pipeline(steps=[('robustscaler',
#                                                   RobustScaler())]),
#                                  ['remaining_plan_duration', 'usage_from_ltd',
#                                   'payment_plan_days', 'plan_list_price',
#                                   'actual_amount_paid', 'num_50', 'num_75',
#                                   'num_985', 'expire_year',
#                                   'last_transaction_year']),
#                                 ('MinMax',
#                                  Pipeline(steps=[('minmaxscaler',
#                                                   MinMaxScaler())]),
#                                  ['registration_year']),
#                                 ('Log',
#                                  Pipeline(steps=[('functiontransformer',
#                                                   FunctionTransformer(func=<ufunc 'log1p'>,
#                                                                       validate=True)),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  ['num_25', 'num_100', 'num_unq',
#                                   'total_secs'])])

# %%
X = data_df.drop(['is_churn'], axis=1)
y= data_df['is_churn']

# %%
# Use fit on X_train and then transform both datasets
preprocessor_new.fit(X)
X_train_transformed = preprocessor_new.transform(X)

X_train_transformed = pd.DataFrame(
    X_train_transformed, 
    columns=X.columns
)

X_train_transformed.head(2)
# Out:
#    payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 0          16.153846        -0.264706               -23.0          -7.45
# 1          -0.038462         0.485294                 0.0           0.00
#
#    is_cancel  remaining_plan_duration  is_discount    num_25  num_50  num_75  \
# 0  -3.040816                 0.588235     0.545455  0.333333     1.0     0.0
# 1   0.000000                -0.235294     0.000000 -0.333333     0.0     0.0
#
#    ...  expire_year  expire_month_sin  expire_month_cos  expire_day_sin  \
# 0  ...    -0.790776         -0.612106          0.500000       -0.866025
# 1  ...    -0.988468          0.151428          0.866025       -0.500000
#
#    expire_day_cos  registration_year  registration_month_sin  \
# 0       -0.299363          -0.954139                     0.5
# 1       -0.998717          -0.050649                     0.5
#
#    registration_month_cos  registration_day_sin  registration_day_cos
# 0                0.866025              0.571268              0.820763
# 1               -0.866025              0.998717             -0.050649
#
# [2 rows x 37 columns]

# %%
model = LogisticRegression(C= 2.58069,
                           solver='liblinear',
 max_iter= 2,
penalty= 'l1',
 class_weight= 'balanced')

# %%
X_train, X_test, y_train, y_test, ids_train, ids_test = train_test_split(X_train_transformed, y, ids, test_size=0.2, stratify=y, random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# /home/nazneen/.pyenv/versions/lewagon/lib/python3.10/site-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LogisticRegression(C=2.58069, class_weight='balanced', max_iter=2, penalty='l1',
#                    solver='liblinear')

# %%
y_pred = model.predict_proba(X_test)
# y_pred = pd.DataFrame(y_pred)
y_pred= y_pred[:,1]

# %%
# from sklearn.metrics import accuracy_score
# accuracy_score(y_test, y_pred)

# %%
pd.DataFrame({'id': ids_test, 'prediction': y_pred, 'check': y_test})
# Out:
#                                                  id  prediction  check
# 29784  RimQ2deT5cLaSJpBXGxsfUFQgrKDtTpMNR+LI/gCP+E=    0.362682      1
# 54227  p2jsQmpCzKg89Rmyj+mskzeDYgp6Vs5iDP+oNb32hDk=    0.253484      1
# 33069  OiC+Sb7HwFPLg5knh0+FoYKeHPca9UsARMCRh4S9yaM=    0.917324      1
# 10646  oiU/Xn0b7SqMG/rkKIbc/iL6HwCK8YL2hNtbtb9nMhs=    0.168704      0
# 11161  itxTVsNqGnQV4e/pJHDWfdq1tWJfecwbrcj+3nW4T5s=    0.248096      0
# ...                                             ...         ...    ...
# 22469  ewx/ju9oF+xtaX+7pR36o2rYdMEeGtx2/4LkpIomJBE=    0.202245      0
# 11980  4RGMZZ15vO/I4qlI2rAlsa2a1JH7hovrDc6iZJvR5BI=    0.264740      0
# 45499  JCodGh7XZXEbkGE24za+0qaDc8oDGouMrfxicf/R6NM=    0.389913      1
# 42462  PfynSfWrNQ7FQBvhmLscWk6t/q+CWmAemWnQlhbXQ1Q=    0.614611      1
# 28221  NSGtQJPZ9H3u0aPuzaDyTTcdaniKvyGaxSwZYUzk4gY=    0.895675      1
#
# [11199 rows x 3 columns]

# %%
X_tr, X_te, y_tr, y_te, ids_tra, ids_te = train_test_split(X,y, ids, test_size=0.2, stratify=y, random_state=42)

# %%
merged = X_te.merge(ids_te, left_index=True, right_index=True)
merged
# Out:
#        payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 29784               30.0             99.0                99.0            1.0
# 54227               30.0            149.0               149.0            1.0
# 33069               30.0            149.0               149.0            1.0
# 10646               30.0             99.0                99.0            1.0
# 11161               30.0            129.0               129.0            1.0
# ...                  ...              ...                 ...            ...
# 22469               30.0             99.0                99.0            1.0
# 11980               30.0            180.0               180.0            1.0
# 45499               30.0            149.0               149.0            1.0
# 42462               30.0            149.0               149.0            1.0
# 28221               30.0            149.0               149.0            1.0
#
#        is_cancel  remaining_plan_duration  is_discount  num_25  num_50  \
# 29784        0.0                       72            0    74.0    13.0
# 54227        0.0                       35            0    24.0     9.0
# 33069        1.0                       41            0    35.0    13.0
# 10646        0.0                       31            0     0.0     0.0
# 11161        0.0                       31            0     6.0     3.0
# ...          ...                      ...          ...     ...     ...
# 22469        0.0                       31            0    15.0    10.0
# 11980        0.0                       43            0     0.0     0.0
# 45499        0.0                       68            0    55.0     9.0
# 42462        0.0                      126            0    16.0    10.0
# 28221        1.0                       29            0     1.0     0.0
#
#        num_75  ...  expire_month_sin  expire_month_cos  expire_day_sin  \
# 29784     9.0  ...          0.500000         -0.866025       -0.848644
# 54227     7.0  ...          0.866025         -0.500000       -0.485302
# 33069    10.0  ...          0.866025         -0.500000       -0.848644
# 10646     0.0  ...          0.866025         -0.500000       -0.968077
# 11161     7.0  ...          0.866025         -0.500000        0.848644
# ...       ...  ...               ...               ...             ...
# 22469     8.0  ...          0.866025         -0.500000       -0.897805
# 11980     0.0  ...          0.500000         -0.866025        0.651372
# 45499     6.0  ...          0.500000         -0.866025       -0.299363
# 42462     5.0  ...         -0.500000         -0.866025       -0.937752
# 28221     1.0  ...          0.866025         -0.500000        0.299363
#
#        expire_day_cos  registration_year  registration_month_sin  \
# 29784        0.528964               2013           -8.660254e-01
# 54227       -0.874347               2010            8.660254e-01
# 33069        0.528964               2016            8.660254e-01
# 10646       -0.250653               2016           -1.000000e+00
# 11161        0.528964               2013           -1.000000e+00
# ...               ...                ...                     ...
# 22469       -0.440394               2016            5.000000e-01
# 11980       -0.758758               2013           -5.000000e-01
# 45499       -0.954139               2010            5.000000e-01
# 42462        0.347305               2015            1.224647e-16
# 28221       -0.954139               2009           -8.660254e-01
#
#        registration_month_cos  registration_day_sin  registration_day_cos  \
# 29784            5.000000e-01              0.485302             -0.874347
# 54227           -5.000000e-01              0.968077             -0.250653
# 33069            5.000000e-01             -0.968077             -0.250653
# 10646           -1.836970e-16             -0.998717             -0.050649
# 11161           -1.836970e-16             -0.998717             -0.050649
# ...                       ...                   ...                   ...
# 22469            8.660254e-01             -0.897805             -0.440394
# 11980            8.660254e-01              0.848644              0.528964
# 45499            8.660254e-01              0.651372             -0.758758
# 42462           -1.000000e+00             -0.848644              0.528964
# 28221            5.000000e-01              0.571268              0.820763
#
#                                                msno
# 29784  RimQ2deT5cLaSJpBXGxsfUFQgrKDtTpMNR+LI/gCP+E=
# 54227  p2jsQmpCzKg89Rmyj+mskzeDYgp6Vs5iDP+oNb32hDk=
# 33069  OiC+Sb7HwFPLg5knh0+FoYKeHPca9UsARMCRh4S9yaM=
# 10646  oiU/Xn0b7SqMG/rkKIbc/iL6HwCK8YL2hNtbtb9nMhs=
# 11161  itxTVsNqGnQV4e/pJHDWfdq1tWJfecwbrcj+3nW4T5s=
# ...                                             ...
# 22469  ewx/ju9oF+xtaX+7pR36o2rYdMEeGtx2/4LkpIomJBE=
# 11980  4RGMZZ15vO/I4qlI2rAlsa2a1JH7hovrDc6iZJvR5BI=
# 45499  JCodGh7XZXEbkGE24za+0qaDc8oDGouMrfxicf/R6NM=
# 42462  PfynSfWrNQ7FQBvhmLscWk6t/q+CWmAemWnQlhbXQ1Q=
# 28221  NSGtQJPZ9H3u0aPuzaDyTTcdaniKvyGaxSwZYUzk4gY=
#
# [11199 rows x 38 columns]

# %%
to_test = merged.head(10)
to_test.to_csv("to_test3.csv")

to_test
# Out:
#        payment_plan_days  plan_list_price  actual_amount_paid  is_auto_renew  \
# 29784               30.0             99.0                99.0            1.0
# 54227               30.0            149.0               149.0            1.0
# 33069               30.0            149.0               149.0            1.0
# 10646               30.0             99.0                99.0            1.0
# 11161               30.0            129.0               129.0            1.0
# 19168               30.0            149.0               149.0            1.0
# 3672                30.0             99.0                99.0            1.0
# 8338                30.0            149.0               149.0            1.0
# 37743              195.0            894.0               894.0            0.0
# 21082               30.0            180.0               180.0            1.0
#
#        is_cancel  remaining_plan_duration  is_discount  num_25  num_50  \
# 29784        0.0                       72            0    74.0    13.0
# 54227        0.0                       35            0    24.0     9.0
# 33069        1.0                       41            0    35.0    13.0
# 10646        0.0                       31            0     0.0     0.0
# 11161        0.0                       31            0     6.0     3.0
# 19168        0.0                       30            0   321.0    64.0
# 3672         0.0                       31            0    41.0     3.0
# 8338         0.0                       30            0    35.0     2.0
# 37743        0.0                      195            0     9.0     2.0
# 21082        0.0                       30            0    82.0    41.0
#
#        num_75  ...  expire_month_sin  expire_month_cos  expire_day_sin  \
# 29784     9.0  ...          0.500000         -0.866025       -0.848644
# 54227     7.0  ...          0.866025         -0.500000       -0.485302
# 33069    10.0  ...          0.866025         -0.500000       -0.848644
# 10646     0.0  ...          0.866025         -0.500000       -0.968077
# 11161     7.0  ...          0.866025         -0.500000        0.848644
# 19168   181.0  ...          0.866025         -0.500000        0.897805
# 3672      3.0  ...          0.866025         -0.500000       -0.897805
# 8338      2.0  ...          0.866025         -0.500000       -0.201299
# 37743     3.0  ...         -0.866025          0.500000        0.394356
# 21082    29.0  ...          0.866025         -0.500000        0.724793
#
#        expire_day_cos  registration_year  registration_month_sin  \
# 29784        0.528964               2013               -0.866025
# 54227       -0.874347               2010                0.866025
# 33069        0.528964               2016                0.866025
# 10646       -0.250653               2016               -1.000000
# 11161        0.528964               2013               -1.000000
# 19168       -0.440394               2015               -1.000000
# 3672        -0.440394               2014               -0.866025
# 8338         0.979530               2004                1.000000
# 37743        0.918958               2013               -1.000000
# 21082        0.688967               2012               -0.866025
#
#        registration_month_cos  registration_day_sin  registration_day_cos  \
# 29784            5.000000e-01              0.485302             -0.874347
# 54227           -5.000000e-01              0.968077             -0.250653
# 33069            5.000000e-01             -0.968077             -0.250653
# 10646           -1.836970e-16             -0.998717             -0.050649
# 11161           -1.836970e-16             -0.998717             -0.050649
# 19168           -1.836970e-16              0.724793              0.688967
# 3672            -5.000000e-01             -0.394356              0.918958
# 8338             6.123234e-17             -0.394356              0.918958
# 37743           -1.836970e-16              0.201299              0.979530
# 21082           -5.000000e-01             -0.988468              0.151428
#
#                                                msno
# 29784  RimQ2deT5cLaSJpBXGxsfUFQgrKDtTpMNR+LI/gCP+E=
# 54227  p2jsQmpCzKg89Rmyj+mskzeDYgp6Vs5iDP+oNb32hDk=
# 33069  OiC+Sb7HwFPLg5knh0+FoYKeHPca9UsARMCRh4S9yaM=
# 10646  oiU/Xn0b7SqMG/rkKIbc/iL6HwCK8YL2hNtbtb9nMhs=
# 11161  itxTVsNqGnQV4e/pJHDWfdq1tWJfecwbrcj+3nW4T5s=
# 19168  de5YnJjPfHjsKnGhuTLBxBEdckqIlgNwQ62w+AZh64I=
# 3672   /PtkirFI6zuradaatMBakk5UosmB6WFRf3PpbwGVTzc=
# 8338   uGMY46v47o+v/c1f36ao2NUimSnODMJKncV3Ca4OvU8=
# 37743  yYxkPKBEXyqK7KWbBo0OTy8k/UJWmHPoOmYvVI4bnK8=
# 21082  rFNMExdWBTFyUi8nOh0d7rT0RaBBRpORZFF/m9o9MJo=
#
# [10 rows x 38 columns]

# %%
import joblib

# %%
package = {
    'model': model,
    'preprocessor': preprocessor_new  
}

joblib.dump(package, 'package.pkl')
# Out:
# ['package.pkl']
